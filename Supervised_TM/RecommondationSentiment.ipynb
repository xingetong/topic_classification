# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # DataSplit

# %%
dataset_train= pd.read_csv('/content/drive/My Drive/RecommondationCompare/dataset_train.csv', encoding='latin-1');
dataset_train
# Out:
#                                                    text  label  recommend  \
# 0     My opinions on the sentinels have shifted, sti...      0          0
# 1     it is annoying that it does not have workshop/...      0          1
# 2     the game feels more like an aquarium instead o...      0          0
# 3                From desyncing issues, to loss of data      0          0
# 4     It's frustrating not being able to hit anythin...      0          0
# ...                                                 ...    ...        ...
# 1933  This game provides a very strategic and tactic...      1          1
# 1934  RP with learning languages and skills, quest, ...      1          1
# 1935  I still love the game, and it's such an excite...      1          1
# 1936  Characters getting stuck on the map in random ...      0          0
# 1937  I preordered this game because I was so excite...      1          1
#
#       words
# 0        69
# 1        16
# 2        37
# 3         7
# ...

# %%
dataset_train_02, dataset_validation_02 = train_test_split(dataset_train, test_size=0.3, stratify=dataset_train['label'], random_state=42)

# %%
dataset_validation_02
# Out:
#                                                    text  label  recommend  \
# 1081  The only redeeming factor is Graphics, but tha...      1          0
# 903   The only thing IÂd want to see improved is th...      0          1
# 293    IN VIRTUAL REALITY is SO AMAZING it took my b...      1          1
# 1309  Yes you can be a space pirate and pvp or pve w...      1          1
# 1175     One of the best games I've played in a while,       1          1
# ...                                                 ...    ...        ...
# 1757     highly recommend this game to any space lovers      1          1
# 864   Can get repetitive sometimes though, since the...      0          1
# 655   Absolutely no flight physics whatsoever, your ...      0          0
# 1569  your squad maybe being attacked by enemies in ...      1          1
# 727   Now after it has been out a few years, I have ...      1          1
#
#       words
# 1081     33
# 903      35
# 293      20
# 1309     23
# ...

# %%
dataset_train_02
# Out:
#                                                    text  label  recommend  \
# 1389  as an older gamer, who remembers with great af...      1          1
# 1368  There is a story to follow about an alien civ ...      1          1
# 927   This is not only a first-person shooter game w...      1          1
# 14    just as annoying.it has the announcements, the...      0          1
# 1900               you only use one save per franchise       0          1
# ...                                                 ...    ...        ...
# 1176  As for things I want to see added, my issue wi...      0          1
# 1324                  realistic and satisfying as hell.      1          1
# 828   it is the perfect orthographic type 3d simulat...      1          1
# 442    Like a progression system maybe where we coul...      0          1
# 1171  The only downside of the body camera system in...      0          1
#
#       words
# 1389     23
# 1368     23
# 927      19
# 14       15
# ...

# %%
dataset_train_02.to_csv('/content/drive/My Drive/RecommondationCompare/dataset_train_02.csv',index=False)
dataset_validation_02.to_csv('/content/drive/My Drive/RecommondationCompare/dataset_validation_02.csv',index=False)

# %%
data = pd.read_csv('/content/drive/My Drive/RecommondationCompare/pn_data.csv', encoding='latin-1');
data
# Out:
#                                                    text  label  recommend  \
# 0            Camera controls are very well controlling.      1          1
# 1     The game's universe is an expanse so vast and ...      1          0
# 2     It's a fantastic game and I would recommend to...      1          1
# 3     Everything is autopiloted- Feels more casual t...      1          0
# 4     On planet nothing really "challenges" you, you...      1          0
# ...                                                 ...    ...        ...
# 2764  and the in game audio options are very poor le...      0          0
# 2765  This game is still no optimized for MacOS, I'm...      0          0
# 2766  when I load the game it crashes or it doesn't ...      0          0
# 2767  This review will change to a 1 out of 10 and n...      0          1
# 2768  You can only customize weapons here, when it s...      0          0
#
#       words
# 0         6
# 1        43
# 2        10
# 3         9
# ...

# %%
dataset_train, dataset_validation = train_test_split(data, test_size=0.3, stratify=data['label'], random_state=42)

# %%
dataset_train
# Out:
#                                                    text  label  recommend  \
# 2151  My opinions on the sentinels have shifted, sti...      0          0
# 1632  it is annoying that it does not have workshop/...      0          1
# 1745  the game feels more like an aquarium instead o...      0          0
# 2149             From desyncing issues, to loss of data      0          0
# 2220  It's frustrating not being able to hit anythin...      0          0
# ...                                                 ...    ...        ...
# 430   This game provides a very strategic and tactic...      1          1
# 1065  RP with learning languages and skills, quest, ...      1          1
# 642   I still love the game, and it's such an excite...      1          1
# 2462  Characters getting stuck on the map in random ...      0          0
# 651   I preordered this game because I was so excite...      1          1
#
#       words
# 2151     69
# 1632     16
# 1745     37
# 2149      7
# ...

# %%
dataset_validation
# Out:
#                                                    text  label  recommend  \
# 556   I really like this idea and how much I can do ...      1          1
# 796    join the Ready Or Not discord and find some p...      1          1
# 156   the fact there does not seem to have a fail st...      1          1
# 1371  I've had this game for a while now and they've...      1          1
# 1575                         this is an awesome remake.      1          1
# ...                                                 ...    ...        ...
# 1381  This game also makes an effort to remind you y...      1          1
# 774   Multiplayer on Multiplayer mode your can join ...      1          1
# 1902  how most of the planets have life on them, the...      0          0
# 2552   have no idea why but it simply refused to aut...      0          0
# 1711  unless you download mods which are a pain in t...      0          0
#
#       words
# 556      14
# 796      13
# 156      46
# 1371     22
# ...

# %%
dataset_train.to_csv('/content/drive/My Drive/RecommondationCompare/dataset_train.csv',index=False)
dataset_validation.to_csv('/content/drive/My Drive/RecommondationCompare/dataset_validation.csv',index=False)

# %%
dataset_validation= dataset_validation.sort_values('words')
dataset_validation
# Out:
#                                                    text  label  recommend  \
# 271                                       amzing audio       1          1
# 924                                         Great game       1          1
# 609                                incredibly realistic      1          1
# 703                                 love space trading,      1          1
# 33                                funny than expected.       1          1
# ...                                                 ...    ...        ...
# 1614  On a creative note, this game needs a server b...      0          1
# 2117  I think my main gameplay issue is civies using...      0          0
# 1594  Why do I have to choose a taser over a handgun...      0          1
# 2564  Something else that disappoints a lot, is how ...      0          0
# 2092  good game, however the controls for personal c...      0          1
#
#       words
# 271       2
# 924       2
# 609       2
# 703       3
# ...

# %%
dataset_validation_1 = dataset_validation[0:277]
dataset_validation_1
# Out:
#                                                    text  label  recommend  \
# 271                                       amzing audio       1          1
# 924                                         Great game       1          1
# 609                                incredibly realistic      1          1
# 703                                 love space trading,      1          1
# 33                                funny than expected.       1          1
# ...                                                 ...    ...        ...
# 2473  There are numerous issues with physics collide...      0          1
# 1736  my only criticism is this game has a similar i...      0          1
# 1136  AI are insanely difficult, but mission can be ...      1          1
# 1818  I do wish there was more customization to real...      0          1
# 1121  Its a good time killer if you are hooked easi...      1          1
#
#       words
# 271       2
# 924       2
# 609       2
# 703       3
# ...

# %%
dataset_validation_2 = dataset_validation[277:554]
dataset_validation_2
# Out:
#                                                    text  label  recommend  \
# 1540  the humor in it is quite original, the voice a...      1          1
# 17    overall, the game is not difficult, but I hone...      1          1
# 2753  That being said, don't expect any kind of real...      0          1
# 2675  You face a never ending barrage of sentinels a...      0          1
# 814   The base game is great and really shows off th...      1          1
# ...                                                 ...    ...        ...
# 2282  Only downside is due to the sheer amount of co...      0          1
# 2492   would make a few small changes, maybe add a l...      0          1
# 164   And when I play with my friends I love the onl...      1          0
# 2668  Level design could be better.. Maps are too hu...      0          0
# 1409  john wick AI personally I think that they shou...      1          1
#
#       words
# 1540     13
# 17       13
# 2753     13
# 2675     13
# ...

# %%
dataset_validation_3 = dataset_validation[554:833]
dataset_validation_3
# Out:
#                                                    text  label  recommend  \
# 1743  As it stands, I've played all the levels there...      0          1
# 2664  Hell swapping the magazine from your gun is lo...      0          0
# 1977  the game is unbelievably unbalanced (which as ...      0          0
# 2604  to understand gameplay fully and to actually g...      0          0
# 1240  The addition of multiplayer functionality allo...      1          1
# ...                                                 ...    ...        ...
# 1614  On a creative note, this game needs a server b...      0          1
# 2117  I think my main gameplay issue is civies using...      0          0
# 1594  Why do I have to choose a taser over a handgun...      0          1
# 2564  Something else that disappoints a lot, is how ...      0          0
# 2092  good game, however the controls for personal c...      0          1
#
#       words
# 1743     24
# 2664     24
# 1977     24
# 2604     24
# ...

# %%
dataset_validation_1.to_csv('/content/drive/My Drive/RecommondationCompare/dataset_validation_1.csv',index=False)
dataset_validation_2.to_csv('/content/drive/My Drive/RecommondationCompare/dataset_validation_2.csv',index=False)
dataset_validation_3.to_csv('/content/drive/My Drive/RecommondationCompare/dataset_validation_3.csv',index=False)

# %% [markdown]
# # Train

# %%
# !pip install datasets
# !pip install transformers[torch]
# !pip install optuna

# %%
import os
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer, BertForSequenceClassification
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from transformers import Trainer, TrainingArguments
from transformers import pipeline
from datasets import concatenate_datasets, load_dataset
from huggingface_hub import hf_hub_download
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datasets
from datasets import Dataset, Value, ClassLabel, Features
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from transformers import DataCollatorWithPadding
import optuna
from huggingface_hub import notebook_login
from sklearn.model_selection import StratifiedKFold

# %%
# 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
notebook_login()

# %%
dataset = load_dataset("HFFErica/Recommondation", data_files={'train': 'dataset_train_02.csv', 'validation': 'dataset_validation_02.csv'})
dataset
# Out:
# dataset_train_02.csv:   0%|          | 0.00/174k [00:00<?, ?B/s]
# dataset_validation_02.csv:   0%|          | 0.00/74.3k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'recommend', 'words'],
#         num_rows: 1356
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'recommend', 'words'],
#         num_rows: 582
#     })
# })

# %%
test_dataset_01 = load_dataset("HFFErica/Recommondation", data_files={'test': 'dataset_validation_1.csv'})
test_dataset_01
# Out:
# dataset_validation_1.csv:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     test: Dataset({
#         features: ['text', 'label', 'recommend', 'words'],
#         num_rows: 277
#     })
# })

# %%
test_dataset_02 = load_dataset("HFFErica/Recommondation", data_files={'test': 'dataset_validation_2.csv'})
test_dataset_02
# Out:
# dataset_validation_2.csv:   0%|          | 0.00/29.4k [00:00<?, ?B/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     test: Dataset({
#         features: ['text', 'label', 'recommend', 'words'],
#         num_rows: 277
#     })
# })

# %%
test_dataset_03 = load_dataset("HFFErica/Recommondation", data_files={'test': 'dataset_validation_3.csv'})
test_dataset_03
# Out:
# dataset_validation_3.csv:   0%|          | 0.00/63.2k [00:00<?, ?B/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     test: Dataset({
#         features: ['text', 'label', 'recommend', 'words'],
#         num_rows: 277
#     })
# })

# %% [markdown]
# ## Label

# %%
features = dataset["train"].features.copy()
features["label"] = ClassLabel(names=['negative', 'positive'])
def adjust_labels(batch):
    batch["label"] = [sentiment  for sentiment  in batch["label"]]
    return batch

features["recommend"] = ClassLabel(names=['false', 'true'])
def adjust_labels(batch):
    batch["recommend"] = [sentiment  for sentiment  in batch["recommend"]]
    return batch


features = dataset["validation"].features.copy()
features["label"] = ClassLabel(names=['negative', 'positive'])
def adjust_labels(batch):
    batch["label"] = [sentiment  for sentiment  in batch["label"]]
    return batch

features["recommend"] = ClassLabel(names=['false', 'true'])
def adjust_labels(batch):
    batch["recommend"] = [sentiment  for sentiment  in batch["recommend"]]
    return batch
label_dataset = dataset.map(adjust_labels, batched=True, features=features)

# Test_dataset

features = test_dataset_01["test"].features.copy()
features["label"] = ClassLabel(names=['negative', 'positive'])
def adjust_labels(batch):
    batch["label"] = [sentiment  for sentiment  in batch["label"]]
    return batch
features["recommend"] = ClassLabel(names=['false', 'true'])
def adjust_labels(batch):
    batch["recommend"] = [sentiment  for sentiment  in batch["recommend"]]
    return batch
test_label_dataset_01 = test_dataset_01.map(adjust_labels, batched=True, features=features)

features = test_dataset_02["test"].features.copy()
features["recommend"] = ClassLabel(names=['false', 'true'])
def adjust_labels(batch):
    batch["recommend"] = [sentiment  for sentiment  in batch["recommend"]]
    return batch
features["label"] = ClassLabel(names=['negative', 'positive'])
def adjust_labels(batch):
    batch["label"] = [sentiment  for sentiment  in batch["label"]]
    return batch
test_label_dataset_02 = test_dataset_02.map(adjust_labels, batched=True, features=features)

features = test_dataset_03["test"].features.copy()
features["recommend"] = ClassLabel(names=['false', 'true'])
def adjust_labels(batch):
    batch["recommend"] = [sentiment  for sentiment  in batch["recommend"]]
    return batch
features["label"] = ClassLabel(names=['negative', 'positive'])
def adjust_labels(batch):
    batch["label"] = [sentiment  for sentiment  in batch["label"]]
    return batch
test_label_dataset_03 = test_dataset_03.map(adjust_labels, batched=True, features=features)
# Out:
# ...
# Map:   0%|          | 0/277 [00:00<?, ? examples/s]

# %%
label_dataset['train'].features
# Out:
# {'text': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['negative', 'positive'], id=None),
#  'recommend': ClassLabel(names=['false', 'true'], id=None),
#  'words': Value(dtype='int64', id=None)}

# %%
label_dataset['validation'].features
# Out:
# {'text': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['negative', 'positive'], id=None),
#  'recommend': ClassLabel(names=['false', 'true'], id=None),
#  'words': Value(dtype='int64', id=None)}

# %%
test_label_dataset_03['test'].features
# Out:
# {'text': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['negative', 'positive'], id=None),
#  'recommend': ClassLabel(names=['false', 'true'], id=None),
#  'words': Value(dtype='int64', id=None)}

# %% [markdown]
# ## Map

# %%
train_dataset = label_dataset['train']
validation_dataset = label_dataset['validation']
test_dataset_01 = test_label_dataset_01['test']
test_dataset_02 = test_label_dataset_02['test']
test_dataset_03 = test_label_dataset_03['test']

print(train_dataset)
print(validation_dataset)
print(test_dataset_01)
print(test_dataset_02)
print(test_dataset_03)
# Out:
# Dataset({
#     features: ['text', 'label', 'recommend', 'words'],
#     num_rows: 1356
# })
# Dataset({
#     features: ['text', 'label', 'recommend', 'words'],
#     num_rows: 582
# })
# Dataset({
#     features: ['text', 'label', 'recommend', 'words'],
#     num_rows: 277
# })
# Dataset({
#     features: ['text', 'label', 'recommend', 'words'],
#     num_rows: 277
# })
# Dataset({
#     features: ['text', 'label', 'recommend', 'words'],
#     num_rows: 277
# })

# %%
train_dataset = train_dataset.map(lambda examples: {'labels': examples['label']}, batched=True)
validation_dataset = validation_dataset.map(lambda examples: {'labels': examples['label']}, batched=True)
test_dataset_01 = test_dataset_01.map(lambda examples: {'labels': examples['label']}, batched=True)
test_dataset_02 = test_dataset_02.map(lambda examples: {'labels': examples['label']}, batched=True)
test_dataset_03 = test_dataset_03.map(lambda examples: {'labels': examples['label']}, batched=True)
# Out:
# ...
# Map:   0%|          | 0/277 [00:00<?, ? examples/s]

# %% [markdown]
# # Model

# %%
model_id="cardiffnlp/twitter-roberta-base-sentiment-latest"

model = AutoModelForSequenceClassification.from_pretrained(model_id,
                                                           num_labels=train_dataset.features["label"].num_classes,
                                                          ignore_mismatched_sizes=True)
tokenizer = AutoTokenizer.from_pretrained(model_id)
model.config
# Out:
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
MAX_LENGTH = 256
train_dataset = train_dataset.map(lambda e: tokenizer(e['text'], truncation=True, padding='max_length', max_length=MAX_LENGTH), batched=True)
validation_dataset = validation_dataset.map(lambda e: tokenizer(e['text'], truncation=True, padding='max_length', max_length=MAX_LENGTH), batched=True)
test_dataset_01 = test_dataset_01.map(lambda e: tokenizer(e['text'], truncation=True, padding='max_length', max_length=MAX_LENGTH), batched=True)
test_dataset_02 = test_dataset_02.map(lambda e: tokenizer(e['text'], truncation=True, padding='max_length', max_length=MAX_LENGTH), batched=True)
test_dataset_03 = test_dataset_03.map(lambda e: tokenizer(e['text'], truncation=True, padding='max_length', max_length=MAX_LENGTH), batched=True)
# Out:
# ...
# Map:   0%|          | 0/277 [00:00<?, ? examples/s]

# %%
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
validation_dataset.set_format(type='torch', columns=['input_ids',  'attention_mask', 'labels'])
test_dataset_01.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
test_dataset_02.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
test_dataset_03.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])

# %% [markdown]
# ## Hyperparameters search

# %%
def model_init():
    return AutoModelForSequenceClassification.from_pretrained(model_id, return_dict=True)

from sklearn.metrics import f1_score
# Define a function to compute the F1 score
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    f1 = f1_score(labels, predictions, average='weighted')
    return {"f1": f1}

# %%
training_args = TrainingArguments("test",  eval_steps=500, disable_tqdm=True, do_eval=True, evaluation_strategy='steps')
trainer = Trainer(
    args=training_args,
    data_collator=DataCollatorWithPadding(tokenizer),
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    # eval_dataset=test_dataset,
    model_init=model_init,
    compute_metrics=compute_metrics,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def hp_space_optuna(trial):
    return {
        "learning_rate": trial.suggest_float("learning_rate", 1e-5, 5e-5, log=True),
        "num_train_epochs": trial.suggest_int("num_train_epochs", 2, 4),
        "per_device_train_batch_size": trial.suggest_categorical("per_device_train_batch_size", [16, 32, 64]),
    }

# %%
best_run = trainer.hyperparameter_search(direction="maximize", hp_space=hp_space_optuna, n_trials=10)
print(f"Best run: {best_run}")
# Out:
# [I 2024-10-01 17:51:32,859] A new study created in memory with name: no-name-1fa8d657-65da-4619-9d1c-bf6acef4830c
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {'train_runtime': 81.4477, 'train_samples_per_second': 49.946, 'train_steps_per_second': 0.81, 'train_loss': 0.26059526385683, 'epoch': 3.0}
# ...

# %% [markdown]
# ## Trainer

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='macro')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
training_args = TrainingArguments(
    output_dir='./Best_SA_results',          # output directory

    learning_rate=1.775161226558067e-05,
    num_train_epochs=4,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=16,   # batch size for evaluation


    logging_dir='./logs',            # directory for storing logs
    logging_steps=100,
    do_train=True,
    do_eval=True,
    no_cuda=False,
    load_best_model_at_end=True,
    eval_steps=100,
    evaluation_strategy="steps"
)


trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    compute_metrics=compute_metrics
)

train_out = trainer.train()
train_out

# %% [markdown]
# # CM

# %% [markdown]
# ### 01_label

# %%
y_valid = np.array(test_dataset_01["label"])
y_preds = np.argmax(preds_output.predictions, axis=1)

preds_output = trainer.predict(test_dataset_01)
preds_output.metrics

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()


# Confusion matrix
cm = confusion_matrix(y_true, y_preds, normalize="true")
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ### 01_recommond

# %%
y_valid = np.array(test_dataset_01["recommend"])
y_preds = np.argmax(preds_output.predictions, axis=1)

preds_output = trainer.predict(test_dataset_01)
preds_output.metrics

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['False', 'True'])
plt.xlabel('Predicted')
plt.ylabel('Actual - recommend')
plt.title('Confusion Matrix')
plt.show()


# Confusion matrix
cm = confusion_matrix(y_true, y_preds, normalize="true")
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'],  yticklabels=['False', 'True'])
plt.xlabel('Predicted')
plt.ylabel('Actual - recommend')
plt.title('Confusion Matrix')
plt.show()
